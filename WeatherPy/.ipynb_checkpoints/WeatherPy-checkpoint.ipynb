# %% [markdown]
# WeatherPy

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "/Users/matthewvicario/Desktop/Python-API-Challenge/WeatherPy/Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# Perform API Calls

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it's being processed (with the city number and city name).

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = (f"{url}appid={weather_api_key}&units&q=")

countries = []
city_name = []
date = []
cloudiness = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
index_count = 0
set_count = 1

print("Beginning Data Retrieval")     
print("-----------------------------")

for index, city in enumerate(cities, start = 1):
    try:
        w_response = requests.get(query_url + city).json()
        countries.append(w_response["sys"]["country"])
        city_name.append(w_response ["name"])
        date.append(w_response ["dt"])
        cloudiness.append(w_response["clouds"]["all"])
        humidity.append(w_response["main"]["humidity"])
        lat.append(w_response["coord"]["lat"])
        lng.append(w_response["coord"]["lon"])
        max_temp.append(w_response["main"]["temp_max"])
        wind_speed.append(w_response ["wind"] ["speed"])
        
        if index_count > 49:
            index_count = 0
            set_count = set_count + 1
        
        else:
            index_count = index_count + 1   

        print(f"Processing Record {index_count} of Set {set_count} : {city}")
    
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : yukon
# Processing Record 2 of Set 1 : rikitea
# Processing Record 3 of Set 1 : ponta do sol
# Processing Record 4 of Set 1 : albany
# Processing Record 5 of Set 1 : kapaa
# City not found. Skipping...
# Processing Record 6 of Set 1 : saskylakh
# Processing Record 7 of Set 1 : iqaluit
# Processing Record 8 of Set 1 : tiksi
# Processing Record 9 of Set 1 : acapulco
# Processing Record 10 of Set 1 : castro
# Processing Record 11 of Set 1 : hami
# Processing Record 12 of Set 1 : ushuaia
# City not found. Skipping...
# Processing Record 13 of Set 1 : sao joao da barra
# Processing Record 14 of Set 1 : naze
# Processing Record 15 of Set 1 : east london
# Processing Record 16 of Set 1 : cookeville
# Processing Record 17 of Set 1 : ostrovnoy
# Processing Record 18 of Set 1 : hambantota
# Processing Record 19 of Set 1 : touros
# Processing Record 20 of Set 1 : gat
# Processing Record 21 of Set 1 : port lincoln
# Processing Record 22 of Set 1 : hermanus
# Processing Record 23 of Set 1 : samana
# Processing Record 24 of Set 1 : ekhabi
# Processing Record 25 of Set 1 : chumikan
# Processing Record 26 of Set 1 : qesarya
# Processing Record 27 of Set 1 : sur
# Processing Record 28 of Set 1 : georgetown
# Processing Record 29 of Set 1 : new norfolk
# Processing Record 30 of Set 1 : busselton
# City not found. Skipping...
# Processing Record 31 of Set 1 : port elizabeth
# Processing Record 32 of Set 1 : lasa
# City not found. Skipping...
# Processing Record 33 of Set 1 : talaya
# Processing Record 34 of Set 1 : vila franca do campo
# Processing Record 35 of Set 1 : nanpiao
# Processing Record 36 of Set 1 : upernavik
# Processing Record 37 of Set 1 : victoria
# Processing Record 38 of Set 1 : kavaratti
# Processing Record 39 of Set 1 : tczew
# Processing Record 40 of Set 1 : laela
# Processing Record 41 of Set 1 : puerto leguizamo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 34 of Set 4 : murgab
# Processing Record 35 of Set 4 : bom sucesso
# Processing Record 36 of Set 4 : storsteinnes
# Processing Record 37 of Set 4 : sinnamary
# Processing Record 38 of Set 4 : kendari
# Processing Record 39 of Set 4 : severo-kurilsk
# Processing Record 40 of Set 4 : rawalpindi
# Processing Record 41 of Set 4 : port-gentil
# Processing Record 42 of Set 4 : paveh
# Processing Record 43 of Set 4 : ngunguru
# Processing Record 44 of Set 4 : guanica
# Processing Record 45 of Set 4 : naica
# Processing Record 46 of Set 4 : nanortalik
# Processing Record 47 of Set 4 : bacolod
# Processing Record 48 of Set 4 : henties bay
# Processing Record 49 of Set 4 : alexandria
# Processing Record 50 of Set 4 : mount gambier
# Processing Record 0 of Set 5 : maua
# Processing Record 1 of Set 5 : phuket
# Processing Record 2 of Set 5 : pevek
# Processing Record 3 of Set 5 : atuona
# Processing Record 4 of Set 5 : verkhnevilyuysk
# Processing Record 5 of Set 5 : nikolskoye
# Processing Record 6 of Set 5 : khatanga
# Processing Record 7 of Set 5 : vostok
# Processing Record 8 of Set 5 : tuktoyaktuk
# Processing Record 9 of Set 5 : sao paulo de olivenca
# Processing Record 10 of Set 5 : aklavik
# Processing Record 11 of Set 5 : udayagiri
# Processing Record 12 of Set 5 : port blair
# Processing Record 13 of Set 5 : buy
# Processing Record 14 of Set 5 : gorzow wielkopolski
# Processing Record 15 of Set 5 : airai
# Processing Record 16 of Set 5 : stephenville
# Processing Record 17 of Set 5 : bambous virieux
# Processing Record 18 of Set 5 : inhambane
# Processing Record 19 of Set 5 : ugoofaaru
# Processing Record 20 of Set 5 : rovaniemi
# Processing Record 21 of Set 5 : pafos
# Processing Record 22 of Set 5 : manaure
# Processing Record 23 of Set 5 : hilo
# Processing Record 24 of Set 5 : nome
# Processing Record 25 of Set 5 : hobyo
# Processing Record 26 of Set 5 : beringovskiy
# Processing Record 27 of Set 5 : floro
# Processing Record 28 of Set 5 : cabo san lucas
# Processing Record 29 of Set 5 : cherskiy
# Processing Record 30 of Set 5 : mabaruma
# Processing Record 31 of Set 5 : sawakin
# Processing Record 32 of Set 5 : maxixe
# Processing Record 33 of Set 5 : laguna
# Processing Record 34 of Set 5 : harper
# Processing Record 35 of Set 5 : abaza
# Processing Record 36 of Set 5 : bambanglipuro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 5 : sao filipe
# Processing Record 38 of Set 5 : mao
# Processing Record 39 of Set 5 : tchibanga
# Processing Record 40 of Set 5 : agen
# Processing Record 41 of Set 5 : yar-sale
# Processing Record 42 of Set 5 : leningradskiy
# Processing Record 43 of Set 5 : bontang
# Processing Record 44 of Set 5 : belmonte
# City not found. Skipping...
# Processing Record 45 of Set 5 : torbay
# Processing Record 46 of Set 5 : maragogi
# Processing Record 47 of Set 5 : goderich
# Processing Record 48 of Set 5 : pisco
# Processing Record 49 of Set 5 : kavieng
# Processing Record 50 of Set 5 : korla
# Processing Record 0 of Set 6 : provideniya
# Processing Record 1 of Set 6 : dingle
# Processing Record 2 of Set 6 : ust-maya
# Processing Record 3 of Set 6 : vardo
# Processing Record 4 of Set 6 : taoudenni
# Processing Record 5 of Set 6 : bara
# Processing Record 6 of Set 6 : haines junction
# Processing Record 7 of Set 6 : punta alta
# Processing Record 8 of Set 6 : plettenberg bay
# Processing Record 9 of Set 6 : torrington
# Processing Record 10 of Set 6 : teya
# Processing Record 11 of Set 6 : danilov
# Processing Record 12 of Set 6 : lavrentiya
# Processing Record 13 of Set 6 : estelle
# Processing Record 14 of Set 6 : giresun
# Processing Record 15 of Set 6 : bougouni
# Processing Record 16 of Set 6 : bereda
# Processing Record 17 of Set 6 : walvis bay
# Processing Record 18 of Set 6 : charlestown
# Processing Record 19 of Set 6 : hongjiang
# Processing Record 20 of Set 6 : lompoc
# Processing Record 21 of Set 6 : namatanai
# Processing Record 22 of Set 6 : staryy nadym
# Processing Record 23 of Set 6 : tiarei
# City not found. Skipping...
# Processing Record 24 of Set 6 : sao geraldo do araguaia
# Processing Record 25 of Set 6 : mattru
# Processing Record 26 of Set 6 : alofi
# Processing Record 27 of Set 6 : lincoln
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 6 : kalmar
# Processing Record 29 of Set 6 : pangnirtung
# Processing Record 30 of Set 6 : fairlie
# Processing Record 31 of Set 6 : kudahuvadhoo
# City not found. Skipping...
# Processing Record 32 of Set 6 : goragorskiy
# Processing Record 33 of Set 6 : oussouye
# Processing Record 34 of Set 6 : monte patria
# Processing Record 35 of Set 6 : dikson
# Processing Record 36 of Set 6 : half moon bay
# Processing Record 37 of Set 6 : san pedro de tutule
# Processing Record 38 of Set 6 : kaitangata
# Processing Record 39 of Set 6 : coahuayana
# Processing Record 40 of Set 6 : cananeia
# Processing Record 41 of Set 6 : oyama
# Processing Record 42 of Set 6 : palampur
# Processing Record 43 of Set 6 : biltine
# Processing Record 44 of Set 6 : the valley
# Processing Record 45 of Set 6 : tromso
# Processing Record 46 of Set 6 : karratha
# Processing Record 47 of Set 6 : brokopondo
# Processing Record 48 of Set 6 : khani
# Processing Record 49 of Set 6 : esperance
# Processing Record 50 of Set 6 : sola
# Processing Record 0 of Set 7 : port augusta
# Processing Record 1 of Set 7 : nelson bay
# Processing Record 2 of Set 7 : boulder city
# Processing Record 3 of Set 7 : salalah
# Processing Record 4 of Set 7 : meulaboh
# Processing Record 5 of Set 7 : nadym
# Processing Record 6 of Set 7 : chuy
# Processing Record 7 of Set 7 : trairi
# Processing Record 8 of Set 7 : launceston
# Processing Record 9 of Set 7 : banjar
# Processing Record 10 of Set 7 : te anau
# Processing Record 11 of Set 7 : beloha
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 7 : dudinka
# Processing Record 13 of Set 7 : rio grande
# Processing Record 14 of Set 7 : chifeng
# Processing Record 15 of Set 7 : santa ines
# Processing Record 16 of Set 7 : pierre
# Processing Record 17 of Set 7 : oranjestad
# City not found. Skipping...
# Processing Record 18 of Set 7 : necochea
# Processing Record 19 of Set 7 : prescott
# Processing Record 20 of Set 7 : saint-philippe
# Processing Record 21 of Set 7 : katobu
# Processing Record 22 of Set 7 : lakes entrance
# Processing Record 23 of Set 7 : maceio
# Processing Record 24 of Set 7 : shimoda
# Processing Record 25 of Set 7 : howell

# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 10 : sindor
# Processing Record 15 of Set 10 : northam
# Processing Record 16 of Set 10 : santa maria
# Processing Record 17 of Set 10 : howard springs
# Processing Record 18 of Set 10 : muros
# Processing Record 19 of Set 10 : yarim
# Processing Record 20 of Set 10 : trelew
# Processing Record 21 of Set 10 : lumeje
# Processing Record 22 of Set 10 : oeiras do para
# Processing Record 23 of Set 10 : bryan
# Processing Record 24 of Set 10 : grindavik
# Processing Record 25 of Set 10 : kuchera
# Processing Record 26 of Set 10 : arman
# Processing Record 27 of Set 10 : darhan
# Processing Record 28 of Set 10 : darlowo
# Processing Record 29 of Set 10 : paamiut
# Processing Record 30 of Set 10 : saint-pierre
# City not found. Skipping...
# Processing Record 31 of Set 10 : westport
# Processing Record 32 of Set 10 : calvia
# Processing Record 33 of Set 10 : khonsa
# Processing Record 34 of Set 10 : ahuimanu
# Processing Record 35 of Set 10 : qaqortoq
# Processing Record 36 of Set 10 : talcahuano
# Processing Record 37 of Set 10 : selfoss
# Processing Record 38 of Set 10 : hong gai
# Processing Record 39 of Set 10 : kavarskas
# Processing Record 40 of Set 10 : uray
# Processing Record 41 of Set 10 : grand forks
# Processing Record 42 of Set 10 : magadan
# Processing Record 43 of Set 10 : wanning
# Processing Record 44 of Set 10 : salinopolis
# Processing Record 45 of Set 10 : alyangula
# Processing Record 46 of Set 10 : carnarvon
# Processing Record 47 of Set 10 : porto novo
# Processing Record 48 of Set 10 : taksimo
# Processing Record 49 of Set 10 : bonavista
# Processing Record 50 of Set 10 : windhoek
# City not found. Skipping...
# Processing Record 0 of Set 11 : makat
# City not found. Skipping...
# Processing Record 1 of Set 11 : merritt
# Processing Record 2 of Set 11 : saint-francois
# Processing Record 3 of Set 11 : kloulklubed
# Processing Record 4 of Set 11 : srednekolymsk
# Processing Record 5 of Set 11 : aksu
# Processing Record 6 of Set 11 : pakxan
# Processing Record 7 of Set 11 : turuvekere
# Processing Record 8 of Set 11 : kutum
# City not found. Skipping...
# Processing Record 9 of Set 11 : mchinji
# Processing Record 10 of Set 11 : peniche
# Processing Record 11 of Set 11 : sandpoint
# Processing Record 12 of Set 11 : saint andrews
# Processing Record 13 of Set 11 : cabedelo
# Processing Record 14 of Set 11 : horsham
# Processing Record 15 of Set 11 : zhuhai
# Processing Record 16 of Set 11 : odessa
# Processing Record 17 of Set 11 : kusti
# Processing Record 18 of Set 11 : nerchinskiy zavod
# Processing Record 19 of Set 11 : anadyr
# Processing Record 20 of Set 11 : klobuck
# Processing Record 21 of Set 11 : tselinnoye
# Processing Record 22 of Set 11 : tigre
# City not found. Skipping...
# Processing Record 23 of Set 11 : pacific grove
# Processing Record 24 of Set 11 : wadi musa
# Processing Record 25 of Set 11 : axim
# Processing Record 26 of Set 11 : alta floresta
# Processing Record 27 of Set 11 : boa vista
# Processing Record 28 of Set 11 : sao borja
# Processing Record 29 of Set 11 : cardston
# Processing Record 30 of Set 11 : tulagi
# Processing Record 31 of Set 11 : tari
# Processing Record 32 of Set 11 : ridgecrest
# Processing Record 33 of Set 11 : ca mau
# Processing Record 34 of Set 11 : andra
# Processing Record 35 of Set 11 : lewistown
# Processing Record 36 of Set 11 : castlerea
# Processing Record 37 of Set 11 : waipawa
# Processing Record 38 of Set 11 : czluchow
# Processing Record 39 of Set 11 : havre-saint-pierre
# Processing Record 40 of Set 11 : dukat
# Processing Record 41 of Set 11 : havoysund
# Processing Record 42 of Set 11 : nguru
# Processing Record 43 of Set 11 : sungaipenuh
# Processing Record 44 of Set 11 : abadan
# Processing Record 45 of Set 11 : oktyabrskiy
# Processing Record 46 of Set 11 : asfi
# Processing Record 47 of Set 11 : cascais
# Processing Record 48 of Set 11 : shieli
# Processing Record 49 of Set 11 : tabou
# Processing Record 50 of Set 11 : porto belo
# Processing Record 0 of Set 12 : berlevag
# Processing Record 1 of Set 12 : manzhouli
# Processing Record 2 of Set 12 : manta
# City not found. Skipping...
# Processing Record 3 of Set 12 : thinadhoo
# Processing Record 4 of Set 12 : huntsville
# Processing Record 5 of Set 12 : terney
# Processing Record 6 of Set 12 : tynda
# Processing Record 7 of Set 12 : san andres
# Processing Record 8 of Set 12 : morondava
# Processing Record 9 of Set 12 : dubbo
# Processing Record 10 of Set 12 : vila
# Processing Record 11 of Set 12 : tauramena
# Processing Record 12 of Set 12 : forestville
# Processing Record 13 of Set 12 : la fleche
# Processing Record 14 of Set 12 : certegui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# Convert Raw Data to DataFrame

# %%
#Export the city data into a .csv.
#Display the DataFrame
weather_data = {"City": city_name,
                            "Lat": lat, 
                            "Lng": lng, 
                            "Max Temp": max_temp,
                            "Humidity": humidity,
                            "Cloudiness": cloudiness,
                            "Wind Speed": wind_speed,
                            "Country": countries,
                            "Date": date}
weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
weather_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Yukon  35.51  -97.76    301.48        78           0        4.60
# 1         Rikitea -23.12 -134.97    295.84        83         100        6.27
# 2    Ponta do Sol  32.67  -17.10    293.15        79           0        0.37
# 3          Albany  42.60  -73.97    292.59        66           0        1.21
# 4           Kapaa  22.08 -159.32    300.15        83          90        3.60
# ..            ...    ...     ...       ...       ...         ...         ...
# 570          Vila  42.03   -8.16    295.15        60           0        3.10
# 571     Tauramena   5.02  -72.75    293.17        85          26        1.93
# 572   Forestville  38.85  -76.88    301.15        83          75        1.50
# 573     La Flèche  47.70   -0.08    288.71        93          90        2.10
# 574      Cértegui   5.37  -76.60    297.06        95          95        0.69
#
#     Country        Date
# 0        US  1595056575
# 1        PF  1595056576
# 2        PT  1595056577
# 3        US  1595056561
# 4        US  1595056578
# ..      ...         ...
# 570      PT  1595057063
# 571      CO  1595057064
# 572      US  1595056961
# 573      FR  1595057065
# 574      CO  1595057066
#
# [575 rows x 9 columns]

# %%
# Save city data into a csv file
weather_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%

# %%
max_humidity = weather_df["Humidity"].max()
max_humidity
# Out:
# 100

# %% [markdown]
# Plotting the Data
